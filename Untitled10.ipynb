# %% [markdown]
# ##Regression Data Generation

# %%
from sklearn.datasets import make_regression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
from pandas.core.common import random_state
X,y = make_regression(n_samples=1000, n_features=3, n_informative=2,random_state=32)
print(X.shape,y.shape)
# Out:
# (1000, 3) (1000,)

# %%
df = pd.DataFrame(X)
df
# Out:
#             0         1         2
# 0   -0.234574 -1.379567  0.651427
# 1    0.253680  1.484500  1.650742
# 2    0.539060  0.398998 -0.536248
# 3    0.268889  0.489565 -1.145133
# 4    0.438198 -0.798426  0.860755
# ..        ...       ...       ...
# 995  2.933839  1.847836  0.691418
# 996  0.490166  1.121701  0.328548
# 997 -0.139082  0.253900 -0.139226
# 998  0.793912  0.254454  1.227645
# 999  0.403288 -0.807468 -1.473095
#
# [1000 rows x 3 columns]

# %%
df.describe()
# Out:
#                  0            1            2
# count  1000.000000  1000.000000  1000.000000
# mean     -0.017052     0.022806     0.033349
# std       1.043242     0.999223     1.017410
# min      -3.226915    -3.297282    -3.057233
# 25%      -0.712042    -0.709233    -0.628479
# 50%       0.003839     0.043918     0.011643
# 75%       0.696580     0.705054     0.686300
# max       2.973969     3.499904     3.039240

# %%
plt.scatter(X[:,0],y)
plt.title('x1 vs y')
plt.show()

plt.scatter(X[:,1],y)
plt.title('x2 vs y')
plt.show()

plt.scatter(X[:,2],y)
plt.title('x3 vs y')
plt.show()

# %%
# Adding Dummy Feature
f = np.ones((X.shape[0],1))
X = np.append(f,X,axis=1)
print(X)
# Out:
# [[ 1.         -0.234574   -1.37956691  0.65142651]
#  [ 1.          0.2536797   1.48450016  1.65074211]
#  [ 1.          0.53905971  0.39899807 -0.53624839]
#  ...
#  [ 1.         -0.13908193  0.25390026 -0.13922617]
#  [ 1.          0.79391195  0.25445422  1.22764525]
#  [ 1.          0.4032881  -0.80746793 -1.4730951 ]]

# %% [markdown]
# ##Multifeature Linear Regression

# %%
def hypothesis(x,theta):
  ycap = 0
  m = x.shape[0]
  for i in range(m):
    ycap += x[i]*theta[i]
  return ycap

# %%
def error(X,y,theta):
  m,n = X.shape
  err = 0
  for i in range(m):
    ycap = hypothesis(X[i],theta)
    err += (ycap-y[i])**2
  return err/m

# %%
def gradient(X,y,theta):
  m,n = X.shape
  grad = np.zeros((n,))
  for j in range(n):
    for i in range(m):
      ycap = hypothesis(X[i],theta)
      grad[j] += (ycap-y[i])*X[i][j]
  return grad/m

# %%
def gradientDescent(X,y,learning_rate=0.1,epochs=300):
  m,n = X.shape
  err_list = []
  theta = np.zeros((n,))
  for i in range(epochs):
    err = error(X,y,theta)
    err_list.append(err)
    grad = gradient(X,y,theta)
    for j in range(n):
      theta[j] -= learning_rate*grad[j]
  return theta,err_list

# %%
def r2Score(y,ycap):
  num = np.sum((y-ycap)**2)
  dem = np.sum((y-ycap.mean())**2)
  score = 1 - (num/dem)
  return score*100

# %%
theta, err_list = gradientDescent(X,y)

# %%
print(theta)
# Out:
# [1.99468519e-13 7.03769458e+01 8.71941196e-12 8.96012017e+01]

# %%
plt.plot(err_list)
plt.show()

# %%
ycap = []
for i in range(X.shape[0]):
  y_ = hypothesis(X[i],theta)
  ycap.append(y_)
ycap = np.array(ycap)

# %%
r2Score(y,ycap)
# Out:
# 100.0

# %%
for i in range(50):
  print(f'y = {y[i]}, ypred = {ycap[i]}')
